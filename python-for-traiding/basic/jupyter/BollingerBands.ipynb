# %%
def Bollinger_Bands (data, n): 
    
    # Calculating the moving average
    MA = data['CLOSE'].rolling(window=n).mean() 
    
    # Calculating the standard deviation
    SD = data['CLOSE'].rolling(window=n).std() 
  
    data['Lower_BB'] = MA - (2 * SD) # Lower Bollinger Band
    data['Upper_BB'] = MA + (2 * SD) # Upper Bollinger Band
   
    return data

# %%
## Load and view Nifty data
import pandas as pd
nifty = pd.read_csv('infy_data.csv')
# nifty.head()

# %%
# Calling Bollinger Bands for 'Nifty' index price data 

n = 5 # We have kept the window of the moving average as 21 days

nifty_bb = Bollinger_Bands(nifty, n) # Calling the Bollinger Bands function cerated by us

nifty_bb.tail()
# Out:
#            Date series     OPEN     HIGH      LOW  PREV. CLOSE      ltp  \
# 17  22-Jan-2021     EQ  1327.00  1356.00  1326.55      1339.70  1336.00
# 18  21-Jan-2021     EQ  1350.00  1361.05  1335.00      1339.45  1342.00
# 19  20-Jan-2021     EQ  1320.55  1348.40  1320.55      1316.65  1338.85
# 20  19-Jan-2021     EQ  1320.00  1331.00  1312.00      1312.05  1319.35
# 21  18-Jan-2021     EQ  1338.00  1340.00  1306.00      1344.95  1311.00
#
#       CLOSE     vwap   52W H   52W L   VOLUME              VALUE  \
# 17  1340.85  1344.65  1392.8  509.25  9646591  12,971,261,022.25
# 18  1339.70  1344.32  1392.8  509.25  6142421   8,257,354,257.80
# 19  1339.45  1338.37  1392.8  509.25  8225838  11,009,221,845.75
# 20  1316.65  1320.27  1392.8  509.25  5585744   7,374,694,216.10
# 21  1312.05  1320.52  1392.8  509.25  8861765  11,702,148,822.35
#
#     No of trades     Lower_BB     Upper_BB
# 17        188343  1215.707683  1377.172317
# 18        156050  1261.167491  1371.972509
# 19        195330  1295.115997  1363.324003
# 20        178275  1310.538650  1354.161350
# 21        230056  1301.434488  1358.045512

# %%
# Plotting the Bollinger Bands for "Nifty' index
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(10,5))

plt.plot(nifty_bb.CLOSE)
plt.plot(nifty_bb.Lower_BB)
plt.plot(nifty_bb.Upper_BB)
plt.grid(True)

plt.show()
